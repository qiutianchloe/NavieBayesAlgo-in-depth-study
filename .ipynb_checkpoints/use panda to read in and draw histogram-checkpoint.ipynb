# %%
import pandas as pd
import numpy as np
wine =  pd.read_csv("datasets/wine.data_copy", header = 0)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
wine
# Out:
#      Alcohol    age  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0          1  14.23        1.71  2.43               15.6        127
# 1          1  13.20        1.78  2.14               11.2        100
# 2          1  13.16        2.36  2.67               18.6        101
# 3          1  14.37        1.95  2.50               16.8        113
# 4          1  13.24        2.59  2.87               21.0        118
# ..       ...    ...         ...   ...                ...        ...
# 173        3  13.71        5.65  2.45               20.5         95
# 174        3  13.40        3.91  2.48               23.0        102
# 175        3  13.27        4.28  2.26               20.0        120
# 176        3  13.17        2.59  2.37               20.0        120
# 177        3  14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# 1             2.65        2.76                  0.26             1.28
# 2             2.80        3.24                  0.30             2.81
# 3             3.85        3.49                  0.24             2.18
# 4             2.80        2.69                  0.39             1.82
# ..             ...         ...                   ...              ...
# 173           1.68        0.61                  0.52             1.06
# 174           1.80        0.75                  0.43             1.41
# 175           1.59        0.69                  0.43             1.35
# 176           1.65        0.68                  0.53             1.46
# 177           2.05        0.76                  0.56             1.35
#
#      Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0               5.64  1.04                          3.92     1065
# 1               4.38  1.05                          3.40     1050
# 2               5.68  1.03                          3.17     1185
# 3               7.80  0.86                          3.45     1480
# 4               4.32  1.04                          2.93      735
# ..               ...   ...                           ...      ...
# 173             7.70  0.64                          1.74      740
# 174             7.30  0.70                          1.56      750
# 175            10.20  0.59                          1.56      835
# 176             9.30  0.60                          1.62      840
# 177             9.20  0.61                          1.60      560
#
# [178 rows x 14 columns]

# %%
y = wine['Ash']
x = [i for i in range(178)]
# plt.scatter(x, y) 
# plt.xticks([])
# plt.yticks([])
# plt.show()

# plt.plot(x, y)
# plt.show()

plt.hist(y, bins = 20,color = 'steelblue', edgecolor = 'k', label = 'historgram') 

#从图上可以看出这是一个normal distribution
# Out:
# (array([ 1.,  0.,  0.,  3.,  2.,  5.,  8.,  6., 18., 25., 30., 24., 13.,
#         18., 17.,  3.,  3.,  0.,  0.,  2.]),
#  array([1.36  , 1.4535, 1.547 , 1.6405, 1.734 , 1.8275, 1.921 , 2.0145,
#         2.108 , 2.2015, 2.295 , 2.3885, 2.482 , 2.5755, 2.669 , 2.7625,
#         2.856 , 2.9495, 3.043 , 3.1365, 3.23  ]),
#  <a list of 20 Patch objects>)

# %%
y = wine['Alcalinity of ash']
# x = [i for i in range(178)]
# plt.scatter(x, y) 
# plt.xticks([])
# plt.yticks([])
# plt.show()
plt.hist(y, bins = 20,color = 'steelblue', edgecolor = 'k', label = 'historgram')
# Out:
# (array([ 3.,  2.,  1.,  2.,  6., 18., 15., 17., 23., 24., 18., 16., 11.,
#          7.,  8.,  2.,  2.,  0.,  2.,  1.]),
#  array([10.6 , 11.57, 12.54, 13.51, 14.48, 15.45, 16.42, 17.39, 18.36,
#         19.33, 20.3 , 21.27, 22.24, 23.21, 24.18, 25.15, 26.12, 27.09,
#         28.06, 29.03, 30.  ]),
#  <a list of 20 Patch objects>)

# %%
plt.figure()
for index, row in wine.iteritems(): 
    plt.hist(wine[index], bins = 40,color = 'steelblue', edgecolor = 'k', label = 'historgram') 
    plt.title(index)
    plt.show()

# %%
# plt.figure
# plt.subplot(130+1) 
# plt.hist(wine['age'], bins = 30,color = 'steelblue', edgecolor = 'k', label = 'historgram') 
# plt.subplot(132) 
# plt.hist(wine['Malic acid'], bins = 30,color = 'steelblue', edgecolor = 'k', label = 'historgram')
# plt.subplot(133)
# plt.hist(wine['Ash'], bins = 30,color = 'steelblue', edgecolor = 'k', label = 'historgram')
# plt.show()
